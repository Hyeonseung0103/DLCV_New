# %% [markdown]
# ### MMDetection 설치
# * 강의 영상에는 pip install mmcv-full로 mmcv를 설치(약 10분 정도의 시간이 소요)
# * 실습코드는 pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu116/torch1.13/index.html 로 변경(설치에 12초 정도 걸림. 2022.09).
# * 코랩의 pytorch 버전이 2.0으로 upgrade되었으나 mmdetection은 아직 pytorch 2.0을 지원하지 않기에 pytorch 1.13으로 downgrade 필요(2023.04월에 코랩 pytorch upgrade)
# *  2023년 4월 6일 기준으로 mmdetection이 3.0으로 upgrade됨. 실습 코드는 mmdetection 2.x 기준으므로 mmdetection 2.x 소스코드 설치 필요.

# %%
#코랩의 pytorch 버전이 2.0으로 upgrade됨.
import torch
print(torch.__version__)
# Out:
# 1.13.0+cu116

# %%
#현재 mmdetection이 pytorch 2.x를 지원하지 않음. pytorch 1.13+ CUDA 116 환경으로 코랩 커널 downgrade
# downgrade 설치시 ERROR: pip's dependency resolver... 부분은 신경쓰지 않아도 됨.
# !pip install -q torch==1.13.0+cu116 torchvision==0.14.0+cu116 --extra-index-url https://download.pytorch.org/whl/cu116

# %%
# mmcv를 위해서 mmcv-full을 먼저 설치해야 함. https://mmcv.readthedocs.io/en/latest/get_started/installation.html 설치 과정 참조.
# !pip install -q mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu116/torch1.13/index.html

# %%
# 2023년 4월 6일 기준으로 mmdetection이 3.0으로 upgrade됨. 실습 코드는 mmdetection 2.x 기준임.
# mmdetection 2.x branch의 소스코드 기반으로 mmdetection 설치 필요.
# !git clone --branch 2.x https://github.com/open-mmlab/mmdetection.git
# !cd mmdetection; python setup.py install

# %%
# !pip install -q yapf==0.40.1 # pretty text를 위해서 설치

# %%
# 런타임->런타임 다시 시작 후 아래 수행.
from mmdet.apis import init_detector, inference_detector
import mmcv
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(

# %% [markdown]
# ### PASCAL VOC 2007 데이터 세트 다운로드

# %%
# !wget http://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# !tar -xvf VOCtrainval_06-Nov-2007.tar > /dev/null 2>&1

# %% [markdown]
# ### MMDetection은 Mask RCNN을 학습하기 위해서는 COCO 포맷을 가장 선호
# * CocoDataset으로 지정해야만, evaluation 시 mask evaluation 정보 제공.(2021년 6월 기준) https://mmdetection.readthedocs.io/en/latest/tutorials/customize_dataset.html
# * Pascal voc 포맷을 Coco 포맷으로 변환할 수 있는 유틸리티를 활용하여 데이터 변환
# https://github.com/ISSResearch/Dataset-Converters
# * Dataset converter 패키지가 opencv를 3.4로 downgrade함에 유의

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.8.0

# %%
# !git clone https://github.com/ISSResearch/Dataset-Converters.git
# !cd Dataset-Converters; pip install -q -r requirements.txt

# %%
# !mkdir /content/coco_output
# !cd Dataset-Converters;python convert.py --input-folder /content/VOCdevkit/VOC2007 --output-folder /content/coco_output \
                  --input-format VOCSEGM --output-format COCO --copy

# %%
# !pip install -q opencv-python

# %% [markdown]
# ### 생성된 Coco Annotation json 파일 살펴 보기

# %%
# !sudo apt-get install jq

# %%
# !jq . /content/coco_output/annotations/train.json > output.json

# %%
# !head -20 output.json
# Out:
# {
#   "images": [
#     {
#       "file_name": "000032.jpg",
#       "height": 281,
#       "width": 500,
#       "id": 1
#     },
#     {
#       "file_name": "000033.jpg",
#       "height": 366,
#       "width": 500,
#       "id": 2
#     },
#     {
#       "file_name": "000042.jpg",
#       "height": 335,
#       "width": 500,
#       "id": 3
#     },

# %%
# !grep -n 'annotations' output.json
# Out:
# 1259:  "annotations": [

# %%
# !head -1600 output.json | tail -400
# Out:
#       "id": 200
#     },
#     {
#       "file_name": "009654.jpg",
#       "height": 500,
#       "width": 333,
#       "id": 201
#     },
#     {
#       "file_name": "009684.jpg",
#       "height": 375,
#       "width": 500,
#       "id": 202
#     },
#     {
#       "file_name": "009691.jpg",
#       "height": 333,
#       "width": 500,
#       "id": 203
#     },
#     {
#       "file_name": "009709.jpg",
#       "height": 500,
#       "width": 375,
#       "id": 204
#     },
#     {
#       "file_name": "009756.jpg",
#       "height": 375,
#       "width": 500,
#       "id": 205
#     },
#     {
#       "file_name": "009807.jpg",
#       "height": 333,
#       "width": 500,
#       "id": 206
#     },
#     {
#       "file_name": "009832.jpg",
#       "height": 375,
#       "width": 500,
#       "id": 207
#     },
#     {
#       "file_name": "009911.jpg",
#       "height": 400,
#       "width": 500,
#       "id": 208
#     },
#     {
#       "file_name": "009938.jpg",
#       "height": 375,
#       "width": 500,
#       "id": 209
#     }
#   ],
#   "type": "instances",
#   "annotations": [
#     {
#       "segmentation": [
#         [
#           234,
#           106,
#           232,
#           108,
#           230,
#           108,
#           228,
#           110,
#           227,
#           110,
#           226,
#           111,
#           216,
#           111,
#           215,
#           110,
#           214,
#           111,
#           213,
#           111,
#           212,
#           112,
#           212,
#           113,
#           213,
#           114,
#           213,
#           115,
#           212,
#           116,
#           210,
#           116,
#           204,
#           122,
#           204,
#           123,
#           202,
#           125,
#           202,
#           127,
#           200,
#           129,
#           200,
#           131,
#           199,
#           132,
#           189,
#           132,
#           188,
#           131,
#           187,
#           131,
#           186,
#           130,
#           170,
#           130,
#           169,
#           129,
#           162,
#           129,
#           161,
#           128,
#           150,
#           128,
#           149,
#           127,
#           106,
#           127,
#           105,
#           128,
#           106,
#           129,
#           109,
#           129,
#           111,
#           131,
#           147,
#           131,
#           148,
#           132,
#           159,
#           132,
#           160,
#           133,
#           162,
#           133,
#           163,
#           134,
#           183,
#           134,
#           184,
#           135,
#           194,
#           135,
#           196,
#           137,
#           198,
#           135,
#           199,
#           136,
#           199,
#           153,
#           200,
#           154,
#           200,
#           156,
#           201,
#           157,
#           201,
#           158,
#           205,
#           162,
#           207,
#           162,
#           208,
#           163,
#           208,
#           164,
#           212,
#           168,
#           212,
#           173,
#           211,
#           174,
#           211,
#           175,
#           212,
#           176,
#           212,
#           177,
#           214,
#           179,
#           214,
#           180,
#           216,
#           182,
#           220,
#           182,
#           222,
#           180,
#           224,
#           182,
#           225,
#           181,
#           225,
#           179,
#           228,
#           176,
#           228,
#           175,
#           227,
#           174,
#           228,
#           173,
#           225,
#           170,
#           225,
#           166,
#           224,
#           165,
#           225,
#           164,
#           228,
#           164,
#           229,
#           163,
#           231,
#           163,
#           235,
#           159,
#           236,
#           159,
#           237,
#           158,
#           237,
#           157,
#           238,
#           156,
#           239,
#           156,
#           240,
#           155,
#           240,
#           153,
#           245,
#           148,
#           245,
#           146,
#           246,
#           145,
#           245,
#           144,
#           245,
#           142,
#           246,
#           141,
#           246,
#           139,
#           245,
#           138,
#           245,
#           137,
#           246,
#           136,
#           247,
#           137,
#           249,
#           137,
#           250,
#           138,
#           249,
#           139,
#           249,
#           140,
#           250,
#           141,
#           254,
#           141,
#           255,
#           140,
#           257,
#           140,
#           258,
#           139,
#           258,
#           138,
#           259,
#           137,
#           262,
#           137,
#           263,
#           138,
#           263,
#           146,
#           262,
#           147,
#           261,
#           147,
#           260,
#           146,
#           259,
#           147,
#           259,
#           154,
#           260,
#           155,
#           261,
#           154,
#           261,
#           148,
#           262,
#           147,
#           263,
#           148,
#           263,
#           150,
#           264,
#           151,
#           265,
#           150,
#           266,
#           151,
#           266,
#           155,
#           267,
#           156,
#           268,
#           155,
#           268,
#           147,
#           267,
#           146,
#           266,
#           147,
#           265,
#           146,
#           265,
#           140,
#           266,
#           139,
#           266,
#           138,
#           267,
#           137,
#           277,
#           137,
#           278,
#           136,
#           285,
#           136,
#           286,
#           135,
#           324,
#           135,
#           327,
#           132,
#           334,
#           132,
#           335,
#           131,
#           344,
#           131,
#           345,
#           130,
#           360,
#           130,
#           361,
#           129,
#           373,
#           129,
#           374,
#           128,
#           373,
#           127,
#           361,
#           127,
#           360,
#           128,
#           345,
#           128,
#           344,
#           129,
#           335,
#           129,
#           334,
#           130,
#           326,
#           130,
#           325,
#           131,
#           294,
#           131,
#           293,
#           132,
#           284,
#           132,
#           283,
#           133,

# %% [markdown]
# ### Pretrained 모델 다운로드 및 Config, Dataset설정.

# %%
# pretrained weight 모델을 다운로드 받기 위해서 mmdetection/checkpoints 디렉토리를 만듬.
# !cd mmdetection; mkdir checkpoints

# %%
# !wget -O /content/mmdetection/checkpoints/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth http://download.openmmlab.com/mmdetection/v2.0/mask_rcnn/mask_rcnn_r101_fpn_1x_coco/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth
# Out:
# --2023-11-19 11:37:14--  http://download.openmmlab.com/mmdetection/v2.0/mask_rcnn/mask_rcnn_r101_fpn_1x_coco/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth
# Resolving download.openmmlab.com (download.openmmlab.com)... 47.246.48.207, 47.246.48.204, 47.246.48.209, ...
# Connecting to download.openmmlab.com (download.openmmlab.com)|47.246.48.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 254089599 (242M) [application/octet-stream]
# Saving to: ‘/content/mmdetection/checkpoints/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth’
#
# /content/mmdetectio 100%[===================>] 242.32M  27.3MB/s    in 9.4s
#
# 2023-11-19 11:37:24 (25.7 MB/s) - ‘/content/mmdetection/checkpoints/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth’ saved [254089599/254089599]

# %%
# !ls -lia /content/mmdetection/checkpoints
# Out:
# total 248144
# 2243916 drwxr-xr-x  2 root root      4096 Nov 19 10:55 .
# 2228335 drwxr-xr-x 19 root root      4096 Nov 19 10:55 ..
# 2243917 -rw-r--r--  1 root root 254089599 Nov  2  2021 mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth

# %%
# config 파일을 설정하고, 다운로드 받은 pretrained 모델을 checkpoint로 설정.
config_file = '/content/mmdetection/configs/mask_rcnn/mask_rcnn_r101_fpn_1x_coco.py'
checkpoint_file = '/content/mmdetection/checkpoints/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth'

# %%
from mmdet.datasets.builder import DATASETS
from mmdet.datasets.coco import CocoDataset

@DATASETS.register_module(force=True)
class VOCDataset(CocoDataset):
  CLASSES = ('aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car',
               'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse',
               'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train',
               'tvmonitor')

# %%
from mmcv import Config

cfg = Config.fromfile(config_file)
print(cfg.pretty_text)
# Out:
# model = dict(
#     type='MaskRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=101,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained',
#                       checkpoint='torchvision://resnet101')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=80,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#         mask_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=14, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         mask_head=dict(
#             type='FCNMaskHead',
#             num_convs=4,
#             in_channels=256,
#             conv_out_channels=256,
#             num_classes=80,
#             loss_mask=dict(
#                 type='CrossEntropyLoss', use_mask=True, loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             mask_size=28,
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100,
#             mask_thr_binary=0.5)))
# dataset_type = 'CocoDataset'
# data_root = 'data/coco/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels', 'gt_masks'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_train2017.json',
#         img_prefix='data/coco/train2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(
#                 type='Collect',
#                 keys=['img', 'gt_bboxes', 'gt_labels', 'gt_masks'])
#         ]),
#     val=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(metric=['bbox', 'segm'])
# optimizer = dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=50, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=16)

# %%
from mmdet.apis import set_random_seed

# dataset에 대한 환경 파라미터 수정.
cfg.dataset_type = 'VOCDataset'
cfg.data_root = '/content/coco_output/'

# train, val, test dataset에 대한 type, data_root, ann_file, img_prefix 환경 파라미터 수정.
cfg.data.train.type = 'VOCDataset'
cfg.data.train.data_root = '/content/coco_output/'
cfg.data.train.ann_file = 'annotations/train.json'
cfg.data.train.img_prefix = 'train'

cfg.data.val.type = 'VOCDataset'
cfg.data.val.data_root = '/content/coco_output/'
cfg.data.val.ann_file = 'annotations/val.json'
cfg.data.val.img_prefix = 'val'


# class의 갯수를 pascal voc로 설정.  수정.
cfg.model.roi_head.bbox_head.num_classes = 20
cfg.model.roi_head.mask_head.num_classes = 20

# pretrained 모델
cfg.load_from = '/content/mmdetection/checkpoints/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth'

# 학습 weight 파일로 로그를 저장하기 위한 디렉토리 설정.
cfg.work_dir = './tutorial_exps'

# 학습율 변경 환경 파라미터 설정.
cfg.optimizer.lr = 0.02 / 8
cfg.lr_config.warmup = None
cfg.log_config.interval = 12

# CocoDataset의 경우 metric을 bbox로 설정해야 함.(mAP아님. bbox로 설정하면 mAP를 iou threshold를 0.5 ~ 0.95까지 변경하면서 측정)
cfg.evaluation.metric = ['bbox', 'segm']
cfg.evaluation.interval = 12
cfg.checkpoint_config.interval = 12
cfg.runner.max_epochs = 12

# 두번 config를 로드하면 lr_config의 policy가 사라지는 오류로 인하여 설정.
cfg.lr_config.policy='step'
# Set seed thus the results are more reproducible
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)

# ConfigDict' object has no attribute 'device 오류 발생시 반드시 설정 필요. https://github.com/open-mmlab/mmdetection/issues/7901
cfg.device='cuda'

# %%
print(cfg.pretty_text)
# Out:
# model = dict(
#     type='MaskRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=101,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained',
#                       checkpoint='torchvision://resnet101')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=20,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#         mask_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=14, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         mask_head=dict(
#             type='FCNMaskHead',
#             num_convs=4,
#             in_channels=256,
#             conv_out_channels=256,
#             num_classes=20,
#             loss_mask=dict(
#                 type='CrossEntropyLoss', use_mask=True, loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             mask_size=28,
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100,
#             mask_thr_binary=0.5)))
# dataset_type = 'VOCDataset'
# data_root = '/content/coco_output/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels', 'gt_masks'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='VOCDataset',
#         ann_file='annotations/train.json',
#         img_prefix='train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(
#                 type='Collect',
#                 keys=['img', 'gt_bboxes', 'gt_labels', 'gt_masks'])
#         ],
#         data_root='/content/coco_output/'),
#     val=dict(
#         type='VOCDataset',
#         ann_file='annotations/val.json',
#         img_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         data_root='/content/coco_output/'),
#     test=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(metric=['bbox', 'segm'], interval=12)
# optimizer = dict(type='SGD', lr=0.0025, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup=None,
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=12)
# log_config = dict(interval=12, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = '/content/mmdetection/checkpoints/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth'
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# work_dir = './tutorial_exps'
# seed = 0
# gpu_ids = range(0, 1)
# device = 'cuda'

# %%
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector

# train용 Dataset 생성.
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!

# %%
model = build_detector(cfg.model, train_cfg=cfg.get('train_cfg'), test_cfg=cfg.get('test_cfg'))
model.CLASSES = datasets[0].CLASSES
print(model.CLASSES)
# Out:
# ('aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tvmonitor')

# %%
import os.path as osp
import mmcv

mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
# epochs는 config의 runner 파라미터로 지정됨. 기본 12회에서 20회로 바꿈
train_detector(model, datasets, cfg, distributed=False, validate=True)
# Out:
# 2023-11-19 12:21:35,095 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2023-11-19 12:21:35,129 - mmdet - INFO - load checkpoint from local path: /content/mmdetection/checkpoints/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# 2023-11-19 12:21:35,423 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([21, 1024]).
# size mismatch for roi_head.bbox_head.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([21]).
# size mismatch for roi_head.bbox_head.fc_reg.weight: copying a param with shape torch.Size([320, 1024]) from checkpoint, the shape in current model is torch.Size([80, 1024]).
# size mismatch for roi_head.bbox_head.fc_reg.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([80]).
# size mismatch for roi_head.mask_head.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([20, 256, 1, 1]).
# size mismatch for roi_head.mask_head.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([20]).
# 2023-11-19 12:21:35,438 - mmdet - INFO - Start running, host: root@bc7952bab8a6, work_dir: /content/tutorial_exps
# 2023-11-19 12:21:35,439 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2023-11-19 12:21:35,439 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# 2023-11-19 12:21:35,440 - mmdet - INFO - Checkpoints will be saved to /content/tutorial_exps by HardDiskBackend.
# 2023-11-19 12:21:50,024 - mmdet - INFO - Epoch [1][12/105]	lr: 2.500e-03, eta: 0:25:14, time: 1.214, data_time: 0.222, memory: 5508, loss_rpn_cls: 0.0256, loss_rpn_bbox: 0.0302, loss_cls: 1.1663, acc: 77.4495, loss_bbox: 0.3508, loss_mask: 0.7441, loss: 2.3170
# 2023-11-19 12:22:00,619 - mmdet - INFO - Epoch [1][24/105]	lr: 2.500e-03, eta: 0:21:35, time: 0.883, data_time: 0.029, memory: 5955, loss_rpn_cls: 0.0162, loss_rpn_bbox: 0.0270, loss_cls: 0.5032, acc: 91.3737, loss_bbox: 0.3362, loss_mask: 0.6025, loss: 1.4850
# 2023-11-19 12:22:11,127 - mmdet - INFO - Epoch [1][36/105]	lr: 2.500e-03, eta: 0:20:12, time: 0.876, data_time: 0.023, memory: 5955, loss_rpn_cls: 0.0136, loss_rpn_bbox: 0.0109, loss_cls: 0.4086, acc: 91.2516, loss_bbox: 0.3400, loss_mask: 0.4990, loss: 1.2720
# 2023-11-19 12:22:21,518 - mmdet - INFO - Epoch [1][48/105]	lr: 2.500e-03, eta: 0:19:23, time: 0.866, data_time: 0.021, memory: 5955, loss_rpn_cls: 0.0130, loss_rpn_bbox: 0.0311, loss_cls: 0.3176, acc: 92.8792, loss_bbox: 0.2754, loss_mask: 0.4313, loss: 1.0684
# 2023-11-19 12:22:32,288 - mmdet - INFO - Epoch [1][60/105]	lr: 2.500e-03, eta: 0:18:56, time: 0.897, data_time: 0.023, memory: 5955, loss_rpn_cls: 0.0148, loss_rpn_bbox: 0.
loss_rpn_cls: 0.0021, loss_rpn_bbox: 0.0129, loss_cls: 0.0587, acc: 97.8923, loss_bbox: 0.1262, loss_mask: 0.1265, loss: 0.3264
# 2023-11-19 12:40:15,319 - mmdet - INFO - Epoch [12][60/105]	lr: 2.500e-05, eta: 0:00:38, time: 0.897, data_time: 0.023, memory: 6042, loss_rpn_cls: 0.0018, loss_rpn_bbox: 0.0127, loss_cls: 0.0444, acc: 98.5270, loss_bbox: 0.0859, loss_mask: 0.1226, loss: 0.2674
# 2023-11-19 12:40:26,307 - mmdet - INFO - Epoch [12][72/105]	lr: 2.500e-05, eta: 0:00:28, time: 0.916, data_time: 0.026, memory: 6042, loss_rpn_cls: 0.0011, loss_rpn_bbox: 0.0117, loss_cls: 0.0549, acc: 98.0957, loss_bbox: 0.1072, loss_mask: 0.1516, loss: 0.3266
# 2023-11-19 12:40:36,997 - mmdet - INFO - Epoch [12][84/105]	lr: 2.500e-05, eta: 0:00:17, time: 0.891, data_time: 0.024, memory: 6042, loss_rpn_cls: 0.0011, loss_rpn_bbox: 0.0083, loss_cls: 0.0437, acc: 98.4538, loss_bbox: 0.0911, loss_mask: 0.1251, loss: 0.2692
# 2023-11-19 12:40:47,410 - mmdet - INFO - Epoch [12][96/105]	lr: 2.500e-05, eta: 0:00:07, time: 0.868, data_time: 0.026, memory: 6042, loss_rpn_cls: 0.0013, loss_rpn_bbox: 0.0135, loss_cls: 0.0342, acc: 98.8444, loss_bbox: 0.0763, loss_mask: 0.1162, loss: 0.2415
# 2023-11-19 12:40:55,501 - mmdet - INFO - Saving checkpoint at 12 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 213/213, 5.7 task/s, elapsed: 38s, ETA:     0s
# 2023-11-19 12:41:35,147 - mmdet - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2023-11-19 12:41:35,559 - mmdet - INFO -
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.499
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.785
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.591
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.505
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.607
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.607
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.607
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.615
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.675
#
# 2023-11-19 12:41:35,560 - mmdet - INFO - Evaluating segm...
# DONE (t=0.21s).
# Accumulating evaluation results...
# DONE (t=0.18s).
# Loading and preparing results...
# /usr/local/lib/python3.10/dist-packages/mmdet-2.28.2-py3.10.egg/mmdet/datasets/coco.py:470: UserWarning: The key "bbox" is deleted for more accurate mask AP of small/medium/large instances since v2.12.0. This does not change the overall mAP calculation.
#   warnings.warn(
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.28s).
# Accumulating evaluation results...
# 2023-11-19 12:41:36,126 - mmdet - INFO -
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.460
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.724
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.508
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.166
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.231
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.657
#
# 2023-11-19 12:41:36,139 - mmdet - INFO - Epoch(val) [12][213]	bbox_mAP: 0.4989, bbox_mAP_50: 0.7849, bbox_mAP_75: 0.5907, bbox_mAP_s: 0.2623, bbox_mAP_m: 0.5054, bbox_mAP_l: 0.5645, bbox_mAP_copypaste: 0.4989 0.7849 0.5907 0.2623 0.5054 0.5645, segm_mAP: 0.4600, segm_mAP_50: 0.7244, segm_mAP_75: 0.5077, segm_mAP_s: 0.1660, segm_mAP_m: 0.4161, segm_mAP_l: 0.5825, segm_mAP_copypaste: 0.4600 0.7244 0.5077 0.1660 0.4161 0.5825
# DONE (t=0.24s).

# %% [markdown]
# ### 학습된 모델을 이용하여 단일 이미지와 Video Inference 수행.

# %%
# 에포크 20인데도 마스킹을 하나도 못함
from mmdet.apis import show_result_pyplot

checkpoint_file = '/content/tutorial_exps/epoch_12.pth'

# checkpoint 저장된 model 파일을 이용하여 모델을 생성, 이때 Config는 위에서 update된 config 사용.
model_ckpt = init_detector(cfg, checkpoint_file, device='cuda:0')
# BGR Image 사용
img = cv2.imread('/content/VOCdevkit/VOC2007/JPEGImages/000007.jpg')
#model_ckpt.cfg = cfg

result = inference_detector(model_ckpt, img)
show_result_pyplot(model_ckpt, img, result, score_thr=0.65)
# Out:
# load checkpoint from local path: /content/tutorial_exps/epoch_12.pth

# %% [markdown]
# ### Video Inference 수행
# * get_detected_img()함수를 이용하여 Inference 수행.

# %%
# !wget -O /content/data/London_Street.mp4 https://github.com/chulminkw/DLCV/blob/master/data/video/London_Street.mp4?raw=true
# Out:
# --2023-11-19 12:46:35--  https://github.com/chulminkw/DLCV/blob/master/data/video/London_Street.mp4?raw=true
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/chulminkw/DLCV/raw/master/data/video/London_Street.mp4 [following]
# --2023-11-19 12:46:35--  https://github.com/chulminkw/DLCV/raw/master/data/video/London_Street.mp4
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/chulminkw/DLCV/master/data/video/London_Street.mp4 [following]
# --2023-11-19 12:46:35--  https://raw.githubusercontent.com/chulminkw/DLCV/master/data/video/London_Street.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24928050 (24M) [application/octet-stream]
# Saving to: ‘/content/data/London_Street.mp4’
#
# /content/data/Londo 100%[===================>]  23.77M  --.-KB/s    in 0.1s
#
# 2023-11-19 12:46:35 (233 MB/s) - ‘/content/data/London_Street.mp4’ saved [24928050/24928050]

# %%
import numpy as np

labels_to_names_seq =  {0:'aeroplane', 1:'bicycle', 2:'bird', 3:'boat', 4:'bottle', 5:'bus', 6:'car',
               7:'cat', 8:'chair', 9:'cow', 10:'diningtable', 11:'dog', 12:'horse',
               13:'motorbike', 14:'person', 15:'pottedplant', 16:'sheep', 17:'sofa', 18:'train',
               19:'tvmonitor'}

colors = list(
    [[0, 255, 0],
     [0, 0, 255],
     [255, 0, 0],
     [0, 255, 255],
     [255, 255, 0],
     [255, 0, 255],
     [80, 70, 180],
     [250, 80, 190],
     [245, 145, 50],
     [70, 150, 250]] )

# %%
# model과 원본 이미지 array, filtering할 기준 class confidence score를 인자로 가지는 inference 시각화용 함수 생성.
# 이미 inference 시 mask boolean값이 들어오므로 mask_threshold 값을 필요하지 않음.
def get_detected_img(model, img_array,  score_threshold=0.3, is_print=True):
  # 인자로 들어온 image_array를 복사.
  draw_img = img_array.copy()
  bbox_color=(0, 255, 0)
  text_color=(0, 0, 255)

  # model과 image array를 입력 인자로 inference detection 수행하고 결과를 results로 받음.
  # results는 80개의 2차원 array(shape=(오브젝트갯수, 5))를 가지는 list.
  results = inference_detector(model, img_array)
  bbox_results = results[0]
  seg_results = results[1]

  # 80개의 array원소를 가지는 results 리스트를 loop를 돌면서 개별 2차원 array들을 추출하고 이를 기반으로 이미지 시각화
  # results 리스트의 위치 index가 바로 COCO 매핑된 Class id. 여기서는 result_ind가 class id
  # 개별 2차원 array에 오브젝트별 좌표와 class confidence score 값을 가짐.
  for result_ind, bbox_result in enumerate(bbox_results):
    # 개별 2차원 array의 row size가 0 이면 해당 Class id로 값이 없으므로 다음 loop로 진행.
    if len(bbox_result) == 0:
      continue

    mask_array_list = seg_results[result_ind]

    # 해당 클래스 별로 Detect된 여러개의 오브젝트 정보가 2차원 array에 담겨 있으며, 이 2차원 array를 row수만큼 iteration해서 개별 오브젝트의 좌표값 추출.
    for i in range(len(bbox_result)):
      # 좌상단, 우하단 좌표 추출.
      if bbox_result[i, 4] > score_threshold:
        left = int(bbox_result[i, 0])
        top = int(bbox_result[i, 1])
        right = int(bbox_result[i, 2])
        bottom = int(bbox_result[i, 3])
        caption = "{}: {:.4f}".format(labels_to_names_seq[result_ind], bbox_result[i, 4])
        cv2.rectangle(draw_img, (left, top), (right, bottom), color=bbox_color, thickness=2)
        cv2.putText(draw_img, caption, (int(left), int(top - 7)), cv2.FONT_HERSHEY_SIMPLEX, 0.37, text_color, 1)
        # masking 시각화 적용. class_mask_array는 image 크기 shape의  True/False값을 가지는 2차원 array
        class_mask_array = mask_array_list[i]
        # 원본 image array에서 mask가 True인 영역만 별도 추출.
        masked_roi = draw_img[class_mask_array]
        #color를 임의 지정
        #color_index = np.random.randint(0, len(colors)-1)
        # color를 class별로 지정
        color_index = result_ind % len(colors)
        color = colors[color_index]
        # apply_mask()함수를 적용시 수행 시간이 상대적으로 오래 걸림.
        #draw_img = apply_mask(draw_img, class_mask_array, color, alpha=0.4)
        # 원본 이미지의 masking 될 영역에 mask를 특정 투명 컬러로 적용
        draw_img[class_mask_array] = ([0.3*color[0], 0.3*color[1], 0.3*color[2]] + 0.6 * masked_roi).astype(np.uint8)
        if is_print:
          print(caption)

  return draw_img

# %%
import time

def do_detected_video(model, input_path, output_path, score_threshold, do_print=True):

    cap = cv2.VideoCapture(input_path)

    codec = cv2.VideoWriter_fourcc(*'XVID')

    vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    vid_fps = cap.get(cv2.CAP_PROP_FPS)

    vid_writer = cv2.VideoWriter(output_path, codec, vid_fps, vid_size)

    frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print('총 Frame 갯수:', frame_cnt)
    btime = time.time()
    while True:
        hasFrame, img_frame = cap.read()
        if not hasFrame:
            print('더 이상 처리할 frame이 없습니다.')
            break
        stime = time.time()
        img_frame = get_detected_img(model, img_frame,  score_threshold=score_threshold,is_print=False)
        if do_print:
          print('frame별 detection 수행 시간:', round(time.time() - stime, 4))
        vid_writer.write(img_frame)
    # end of while loop

    vid_writer.release()
    cap.release()

    print('최종 detection 완료 수행 시간:', round(time.time() - btime, 4))

# %%
do_detected_video(model_ckpt, '/content/data/London_Street.mp4', '/content/data/London_Street_out01.mp4', score_threshold=0.65, do_print=True)
# Out:
# 총 Frame 갯수: 489
# frame별 detection 수행 시간: 0.3194
# frame별 detection 수행 시간: 0.2654
# frame별 detection 수행 시간: 0.2565
# frame별 detection 수행 시간: 0.2666
# frame별 detection 수행 시간: 0.2706
# frame별 detection 수행 시간: 0.2712
# frame별 detection 수행 시간: 0.2768
# frame별 detection 수행 시간: 0.268
# frame별 detection 수행 시간: 0.2712
# frame별 detection 수행 시간: 0.2675
# frame별 detection 수행 시간: 0.2704
# frame별 detection 수행 시간: 0.2759
# frame별 detection 수행 시간: 0.277
# frame별 detection 수행 시간: 0.3093
# frame별 detection 수행 시간: 0.3063
# frame별 detection 수행 시간: 0.2829
# frame별 detection 수행 시간: 0.2743
# frame별 detection 수행 시간: 0.2725
# frame별 detection 수행 시간: 0.2816
# frame별 detection 수행 시간: 0.2826
# frame별 detection 수행 시간: 0.2755
# frame별 detection 수행 시간: 0.2751
# frame별 detection 수행 시간: 0.2757
# frame별 detection 수행 시간: 0.2739
# frame별 detection 수행 시간: 0.3257
# frame별 detection 수행 시간: 0.3471
# frame별 detection 수행 시간: 0.3358
# frame별 detection 수행 시간: 0.3227
# frame별 detection 수행 시간: 0.319
# frame별 detection 수행 시간: 0.319
# frame별 detection 수행 시간: 0.3168
# frame별 detection 수행 시간: 0.3211
# frame별 detection 수행 시간: 0.3087
# frame별 detection 수행 시간: 0.3127
# frame별 detection 수행 시간: 0.3148
# frame별 detection 수행 시간: 0.3164
# frame별 detection 수행 시간: 0.3006
# frame별 detection 수행 시간: 0.3082
# frame별 detection 수행 시간: 0.3045
# frame별 detection 수행 시간: 0.3185
# frame별 detection 수행 시간: 0.3194
# frame별 detection 수행 시간: 0.3175
# frame별 detection 수행 시간: 0.3051
# frame별 detection 수행 시간: 0.3027
# frame별 detection 수행 시간: 0.3042
# frame별 detection 수행 시간: 0.3277
# frame별 detection 수행 시간: 0.322
# frame별 detection 수행 시간: 0.3001
# frame별 detection 수행 시간: 0.3005
# frame별 detection 수행 시간: 0.2792
# frame별 detection 수행 시간: 0.283
# frame별 detection 수행 시간: 0.2789
# frame별 detection 수행 시간: 0.2771
# frame별 detection 수행 시간: 0.2663
# frame별 detection 수행 시간: 0.2692
# frame별 detection 수행 시간: 0.2746
# frame별 detection 수행 시간: 0.263
# frame별 detection 수행 시간: 0.2493
# frame별 detection 수행 시간: 0.2649
# frame별 detection 수행 시간: 0.2674
# frame별 detection 수행 시간: 0.2618
# frame별 detection 수행 시간: 0.2657
# frame별 detection 수행 시간: 0.2536
# frame별 detection 수행 시간: 0.2618
# frame별 detection 수행 시간: 0.2653
# frame별 detection 수행 시간: 0.2601
# frame별 detection 수행 시간: 0.2681
# frame별 detection 수행 시간: 0.2587
# frame별 detection 수행 시간: 0.2598
# frame별 detection 수행 시간: 0.2607
# frame별 detection 수행 시간: 0.2635
# frame별 detection 수행 시간: 0.2621
# frame별 detection 수행 시간: 0.2619
# frame별 detection 수행 시간: 0.2675
# frame별 detection 수행 시간: 0.2609
# frame별 detection 수행 시간: 0.2597
# frame별 detection 수행 시간: 0.2746
# frame별 detection 수행 시간: 0.2701
# frame별 detection 수행 시간: 0.2648
# frame별 detection 수행 시간: 0.2709
# frame별 detection 수행 시간: 0.2745
# frame별 detection 수행 시간: 0.2705
# frame별 detection 수행 시간: 0.2717
# frame별 detection 수행 시간: 0.2637
# frame별 detection 수행 시간: 0.2743
# frame별 detection 수행 시간: 0.3231
# frame별 detection 수행 시간: 0.3135
# frame별 detection 수행 시간: 0.309
# frame별 detection 수행 시간: 0.3072
# frame별 detection 수행 시간: 0.6777
# frame별 detection 수행 시간: 0.319
# frame별 detection 수행 시간: 0.3083
# frame별 detection 수행 시간: 0.3114
# frame별 detection 수행 시간: 0.3152
# frame별 detection 수행 시간: 0.3074
# frame별 detection 수행 시간: 0.3066
# frame별 detection 수행 시간: 0.31
# frame별 detection 수행 시간: 0.3036
# frame별 detection 수행 시간: 0.2958
# frame별 detection 수행 시간: 0.2904
# frame별 detection 수행 시간: 0.2823
# frame별 detection 수행 시간: 0.2886
# frame별 detection 수행 시간: 0.2958
# frame별 detection 수행 시간: 0.3032
# frame별 detection 수행 시간: 0.2871
# frame별 detection 수행 시간: 0.2947
# frame별 detection 수행 시간: 0.2897
# frame별 detection 수행 시간: 0.309
# frame별 detection 수행 시간: 0.299
# frame별 detection 수행 시간: 0.2738
# frame별 detection 수행 시간: 0.2703
# frame별 detection 수행 시간: 0.2726
# frame별 detection 수행 시간: 0.2794
# frame별 detection 수행 시간: 0.2771
# frame별 detection 수행 시간: 0.2749
# frame별 detection 수행 시간: 0.2723
# frame별 detection 수행 시간: 0.2718
# frame별 detection 수행 시간: 0.2629
# frame별 detection 수행 시간: 0.2568
# frame별 detection 수행 시간: 0.2628
# frame별 detection 수행 시간: 0.2802
# frame별 detection 수행 시간: 0.2648
# frame별 detection 수행 시간: 0.2595
# frame별 detection 수행 시간: 0.2549
# frame별 detection 수행 시간: 0.2633
# frame별 detection 수행 시간: 0.2675
# frame별 detection 수행 시간: 0.2607
# frame별 detection 수행 시간: 0.2606
# frame별 detection 수행 시간: 0.2562
# frame별 detection 수행 시간: 0.2511
# frame별 detection 수행 시간: 0.255
# frame별 detection 수행 시간: 0.2599
# frame별 detection 수행 시간: 0.258
# frame별 detection 수행 시간: 0.2569
# frame별 detection 수행 시간: 0.2542
# frame별 detection 수행 시간: 0.2512
# frame별 detection 수행 시간: 0.2532
# frame별 detection 수행 시간: 0.2521
# frame별 detection 수행 시간: 0.2583
# frame별 detection 수행 시간: 0.2596
# frame별 detection 수행 시간: 0.25
# frame별 detection 수행 시간: 0.2548
# frame별 detection 수행 시간: 0.2652
# frame별 detection 수행 시간: 0.2555
# frame별 detection 수행 시간: 0.2632
# frame별 detection 수행 시간: 0.2575
# frame별 detection 수행 시간: 0.2991
# frame별 detection 수행 시간: 0.3562
# frame별 detection 수행 시간: 0.4704
# frame별 detection 수행 시간: 0.2845
# frame별 detection 수행 시간: 0.5926
# frame별 detection 수행 시간: 0.2721
# frame별 detection 수행 시간: 0.2736
# frame별 detection 수행 시간: 0.2686
# frame별 detection 수행 시간: 0.2646
# frame별 detection 수행 시간: 0.2758
# frame별 detection 수행 시간: 0.2745
# frame별 detection 수행 시간: 0.2801
# frame별 detection 수행 시간: 0.2867
# frame별 detection 수행 시간: 0.278
# frame별 detection 수행 시간: 0.2817
# frame별 detection 수행 시간: 0.2894
# frame별 detection 수행 시간: 0.2854
# frame별 detection 수행 시간: 0.2835
# frame별 detection 수행 시간: 0.2768
# frame별 detection 수행 시간: 0.2826
# frame별 detection 수행 시간: 0.2864
# frame별 detection 수행 시간: 0.2837
# frame별 detection 수행 시간: 0.29
# frame별 detection 수행 시간: 0.2881
# frame별 detection 수행 시간: 0.2824
# frame별 detection 수행 시간: 0.2496
# frame별 detection 수행 시간: 0.245
# frame별 detection 수행 시간: 0.2498
# frame별 detection 수행 시간: 0.2383
# frame별 detection 수행 시간: 0.2451
# frame별 detection 수행 시간: 0.2483
# frame별 detection 수행 시간: 0.2457
# frame별 detection 수행 시간: 0.249
# frame별 detection 수행 시간: 0.2477
# frame별 detection 수행 시간: 0.2515
# frame별 detection 수행 시간: 0.2521
# frame별 detection 수행 시간: 0.2584
# frame별 detection 수행 시간: 0.2432
# frame별 detection 수행 시간: 0.2511
# frame별 detection 수행 시간: 0.2429
# frame별 detection 수행 시간: 0.2497
# frame별 detection 수행 시간: 0.2509
# frame별 detection 수행 시간: 0.25
# frame별 detection 수행 시간: 0.2575
# frame별 detection 수행 시간: 0.2583
# frame별 detection 수행 시간: 0.257
# frame별 detection 수행 시간: 0.2473
# frame별 detection 수행 시간: 0.2557
# frame별 detection 수행 시간: 0.2567
# frame별 detection 수행 시간: 0.2507
# frame별 detection 수행 시간: 0.2444
# frame별 detection 수행 시간: 0.2477
# frame별 detection 수행 시간: 0.2404
# frame별 detection 수행 시간: 0.2429
# frame별 detection 수행 시간: 0.2443
# frame별 detection 수행 시간: 0.2441
# frame별 detection 수행 시간: 0.2525
# frame별 detection 수행 시간: 0.2546
# frame별 detection 수행 시간: 0.248
# frame별 detection 수행 시간: 0.2497
# frame별 detection 수행 시간: 0.2546
# frame별 detection 수행 시간: 0.2502
# frame별 detection 수행 시간: 0.2528
# frame별 detection 수행 시간: 0.2687
# frame별 detection 수행 시간: 0.2931
# frame별 detection 수행 시간: 0.3031
# frame별 detection 수행 시간: 0.3088
# frame별 detection 수행 시간: 0.2986
# frame별 detection 수행 시간: 0.3015
# frame별 detection 수행 시간: 0.3202
# frame별 detection 수행 시간: 0.3134
# frame별 detection 수행 시간: 0.3123
# frame별 detection 수행 시간: 0.3007
# frame별 detection 수행 시간: 0.3126
# frame별 detection 수행 시간: 0.299
# frame별 detection 수행 시간: 0.3022
# frame별 detection 수행 시간: 0.2971
# frame별 detection 수행 시간: 0.3039
# frame별 detection 수행 시간: 0.3045
# frame별 detection 수행 시간: 0.302
# frame별 detection 수행 시간: 0.2935
# frame별 detection 수행 시간: 0.308
# frame별 detection 수행 시간: 0.2909
# frame별 detection 수행 시간: 0.3071
# frame별 detection 수행 시간: 0.3113
# frame별 detection 수행 시간: 0.3071
# frame별 detection 수행 시간: 0.3014
# frame별 detection 수행 시간: 0.3021
# frame별 detection 수행 시간: 0.2734
# frame별 detection 수행 시간: 0.254
# frame별 detection 수행 시간: 0.2599
# frame별 detection 수행 시간: 0.2627
# frame별 detection 수행 시간: 0.2762
# frame별 detection 수행 시간: 0.2816
# frame별 detection 수행 시간: 0.2765
# frame별 detection 수행 시간: 0.258
# frame별 detection 수행 시간: 0.2639
# frame별 detection 수행 시간: 0.2647
# frame별 detection 수행 시간: 0.2688
# frame별 detection 수행 시간: 0.2599
# frame별 detection 수행 시간: 0.2647
# frame별 detection 수행 시간: 0.2607
# frame별 detection 수행 시간: 0.2616
# frame별 detection 수행 시간: 0.262
# frame별 detection 수행 시간: 0.2544
# frame별 detection 수행 시간: 0.2614
# frame별 detection 수행 시간: 0.2634
# frame별 detection 수행 시간: 0.2639
# frame별 detection 수행 시간: 0.2673
# frame별 detection 수행 시간: 0.2652
# frame별 detection 수행 시간: 0.2649
# frame별 detection 수행 시간: 0.2582
# frame별 detection 수행 시간: 0.263
# frame별 detection 수행 시간: 0.2685
# frame별 detection 수행 시간: 0.2612
# frame별 detection 수행 시간: 0.2655
# frame별 detection 수행 시간: 0.2659
# frame별 detection 수행 시간: 0.2673
# frame별 detection 수행 시간: 0.2607
# frame별 detection 수행 시간: 0.2687
# frame별 detection 수행 시간: 0.2639
# frame별 detection 수행 시간: 0.2677
# frame별 detection 수행 시간: 0.2609
# frame별 detection 수행 시간: 0.2625
# frame별 detection 수행 시간: 0.3009
# frame별 detection 수행 시간: 0.2982
# frame별 detection 수행 시간: 0.2974
# frame별 detection 수행 시간: 0.3161
# frame별 detection 수행 시간: 0.2991
# frame별 detection 수행 시간: 0.2893
# frame별 detection 수행 시간: 0.2903
# frame별 detection 수행 시간: 0.2895
# frame별 detection 수행 시간: 0.2816
# frame별 detection 수행 시간: 0.2867
# frame별 detection 수행 시간: 0.2804
# frame별 detection 수행 시간: 0.2801
# frame별 detection 수행 시간: 0.2973
# frame별 detection 수행 시간: 0.2878
# frame별 detection 수행 시간: 0.2904
# frame별 detection 수행 시간: 0.2855
# frame별 detection 수행 시간: 0.2909
# frame별 detection 수행 시간: 0.2883
# frame별 detection 수행 시간: 0.2923
# frame별 detection 수행 시간: 0.2887
# frame별 detection 수행 시간: 0.2959
# frame별 detection 수행 시간: 0.2904
# frame별 detection 수행 시간: 0.2927
# frame별 detection 수행 시간: 0.2807
# frame별 detection 수행 시간: 0.2748
# frame별 detection 수행 시간: 0.2734
# frame별 detection 수행 시간: 0.257
# frame별 detection 수행 시간: 0.2559
# frame별 detection 수행 시간: 0.2461
# frame별 detection 수행 시간: 0.2492
# frame별 detection 수행 시간: 0.2455
# frame별 detection 수행 시간: 0.2604
# frame별 detection 수행 시간: 0.2468
# frame별 detection 수행 시간: 0.2345
# frame별 detection 수행 시간: 0.2436
# frame별 detection 수행 시간: 0.245
# frame별 detection 수행 시간: 0.2337
# frame별 detection 수행 시간: 0.2339
# frame별 detection 수행 시간: 0.2407
# frame별 detection 수행 시간: 0.2383
# frame별 detection 수행 시간: 0.241
# frame별 detection 수행 시간: 0.236
# frame별 detection 수행 시간: 0.2396
# frame별 detection 수행 시간: 0.2328
# frame별 detection 수행 시간: 0.2459
# frame별 detection 수행 시간: 0.2369
# frame별 detection 수행 시간: 0.2377
# frame별 detection 수행 시간: 0.244
# frame별 detection 수행 시간: 0.2466
# frame별 detection 수행 시간: 0.2525
# frame별 detection 수행 시간: 0.2559
# frame별 detection 수행 시간: 0.2629
# frame별 detection 수행 시간: 0.2671
# frame별 detection 수행 시간: 0.2578
# frame별 detection 수행 시간: 0.2577
# frame별 detection 수행 시간: 0.2584
# frame별 detection 수행 시간: 0.2494
# frame별 detection 수행 시간: 0.2561
# frame별 detection 수행 시간: 0.2501
# frame별 detection 수행 시간: 0.2599
# frame별 detection 수행 시간: 0.2545
# frame별 detection 수행 시간: 0.2572
# frame별 detection 수행 시간: 0.2481
# frame별 detection 수행 시간: 0.2577
# frame별 detection 수행 시간: 0.247
# frame별 detection 수행 시간: 0.2921
# frame별 detection 수행 시간: 0.2866
# frame별 detection 수행 시간: 0.2902
# frame별 detection 수행 시간: 0.282
# frame별 detection 수행 시간: 0.2803
# frame별 detection 수행 시간: 0.2848
# frame별 detection 수행 시간: 0.2898
# frame별 detection 수행 시간: 0.284
# frame별 detection 수행 시간: 0.2742
# frame별 detection 수행 시간: 0.2718
# frame별 detection 수행 시간: 0.2785
# frame별 detection 수행 시간: 0.2781
# frame별 detection 수행 시간: 0.2934
# frame별 detection 수행 시간: 0.2888
# frame별 detection 수행 시간: 0.2843
# frame별 detection 수행 시간: 0.2767
# frame별 detection 수행 시간: 0.2759
# frame별 detection 수행 시간: 0.2731
# frame별 detection 수행 시간: 0.2818
# frame별 detection 수행 시간: 0.2747
# frame별 detection 수행 시간: 0.2752
# frame별 detection 수행 시간: 0.2759
# frame별 detection 수행 시간: 0.279
# frame별 detection 수행 시간: 0.286
# frame별 detection 수행 시간: 0.2819
# frame별 detection 수행 시간: 0.2763
# frame별 detection 수행 시간: 0.2842
# frame별 detection 수행 시간: 0.2551
# frame별 detection 수행 시간: 0.2472
# frame별 detection 수행 시간: 0.2493
# frame별 detection 수행 시간: 0.2506
# frame별 detection 수행 시간: 0.2488
# frame별 detection 수행 시간: 0.248
# frame별 detection 수행 시간: 0.2556
# frame별 detection 수행 시간: 0.2543
# frame별 detection 수행 시간: 0.2519
# frame별 detection 수행 시간: 0.2582
# frame별 detection 수행 시간: 0.2512
# frame별 detection 수행 시간: 0.2608
# frame별 detection 수행 시간: 0.2569
# frame별 detection 수행 시간: 0.2386
# frame별 detection 수행 시간: 0.2601
# frame별 detection 수행 시간: 0.2593
# frame별 detection 수행 시간: 0.2578
# frame별 detection 수행 시간: 0.2545
# frame별 detection 수행 시간: 0.2566
# frame별 detection 수행 시간: 0.2719
# frame별 detection 수행 시간: 0.2564
# frame별 detection 수행 시간: 0.2526
# frame별 detection 수행 시간: 0.2619
# frame별 detection 수행 시간: 0.2502
# frame별 detection 수행 시간: 0.2531
# frame별 detection 수행 시간: 0.257
# frame별 detection 수행 시간: 0.2574
# frame별 detection 수행 시간: 0.2594
# frame별 detection 수행 시간: 0.2615
# frame별 detection 수행 시간: 0.257
# frame별 detection 수행 시간: 0.25
# frame별 detection 수행 시간: 0.2486
# frame별 detection 수행 시간: 0.2544
# frame별 detection 수행 시간: 0.2476
# frame별 detection 수행 시간: 0.2514
# frame별 detection 수행 시간: 0.2511
# frame별 detection 수행 시간: 0.2549
# frame별 detection 수행 시간: 0.2534
# frame별 detection 수행 시간: 0.2942
# frame별 detection 수행 시간: 0.3015
# frame별 detection 수행 시간: 0.307
# frame별 detection 수행 시간: 0.3006
# frame별 detection 수행 시간: 0.3003
# frame별 detection 수행 시간: 0.2994
# frame별 detection 수행 시간: 0.3167
# frame별 detection 수행 시간: 0.2862
# frame별 detection 수행 시간: 0.2944
# frame별 detection 수행 시간: 0.2971
# frame별 detection 수행 시간: 0.2971
# frame별 detection 수행 시간: 0.2971
# frame별 detection 수행 시간: 0.2933
# frame별 detection 수행 시간: 0.3043
# frame별 detection 수행 시간: 0.296
# frame별 detection 수행 시간: 0.2912
# frame별 detection 수행 시간: 0.3049
# frame별 detection 수행 시간: 0.2944
# frame별 detection 수행 시간: 0.2948
# frame별 detection 수행 시간: 0.2958
# frame별 detection 수행 시간: 0.2934
# frame별 detection 수행 시간: 0.2906
# frame별 detection 수행 시간: 0.2997
# frame별 detection 수행 시간: 0.3042
# frame별 detection 수행 시간: 0.3014
# frame별 detection 수행 시간: 0.2614
# frame별 detection 수행 시간: 0.2567
# frame별 detection 수행 시간: 0.2537
# frame별 detection 수행 시간: 0.2521
# frame별 detection 수행 시간: 0.2457
# frame별 detection 수행 시간: 0.26
# frame별 detection 수행 시간: 0.2538
# frame별 detection 수행 시간: 0.2486
# frame별 detection 수행 시간: 0.2484
# frame별 detection 수행 시간: 0.2501
# frame별 detection 수행 시간: 0.2595
# frame별 detection 수행 시간: 0.2576
# frame별 detection 수행 시간: 0.2547
# frame별 detection 수행 시간: 0.2544
# frame별 detection 수행 시간: 0.2588
# frame별 detection 수행 시간: 0.2443
# frame별 detection 수행 시간: 0.2517
# frame별 detection 수행 시간: 0.2629
# frame별 detection 수행 시간: 0.2626
# frame별 detection 수행 시간: 0.2552
# frame별 detection 수행 시간: 0.2633
# frame별 detection 수행 시간: 0.2497
# frame별 detection 수행 시간: 0.2535
# frame별 detection 수행 시간: 0.2478
# frame별 detection 수행 시간: 0.2691
# frame별 detection 수행 시간: 0.2495
# frame별 detection 수행 시간: 0.2542
# frame별 detection 수행 시간: 0.2597
# frame별 detection 수행 시간: 0.2587
# frame별 detection 수행 시간: 0.254
# frame별 detection 수행 시간: 0.2624
# frame별 detection 수행 시간: 0.2555
# frame별 detection 수행 시간: 0.2568
# frame별 detection 수행 시간: 0.2503
# frame별 detection 수행 시간: 0.2528
# frame별 detection 수행 시간: 0.2507
# frame별 detection 수행 시간: 0.2569
# frame별 detection 수행 시간: 0.2519
# frame별 detection 수행 시간: 0.2839
# frame별 detection 수행 시간: 0.3055
# frame별 detection 수행 시간: 0.3024
# frame별 detection 수행 시간: 0.3086
# frame별 detection 수행 시간: 0.2992
# frame별 detection 수행 시간: 0.2987
# frame별 detection 수행 시간: 0.3039
# frame별 detection 수행 시간: 0.2957
# frame별 detection 수행 시간: 0.2964
# frame별 detection 수행 시간: 0.2913
# frame별 detection 수행 시간: 0.2975
# frame별 detection 수행 시간: 0.2866
# frame별 detection 수행 시간: 0.2975
# frame별 detection 수행 시간: 0.2852
# frame별 detection 수행 시간: 0.2878
# frame별 detection 수행 시간: 0.2927
# frame별 detection 수행 시간: 0.2853
# frame별 detection 수행 시간: 0.2905
# frame별 detection 수행 시간: 0.2915
# frame별 detection 수행 시간: 0.2934
# frame별 detection 수행 시간: 0.2989
# frame별 detection 수행 시간: 0.3061
# frame별 detection 수행 시간: 0.3136
# frame별 detection 수행 시간: 0.3003
# frame별 detection 수행 시간: 0.2966
# frame별 detection 수행 시간: 0.2802
# 더 이상 처리할 frame이 없습니다.
# 최종 detection 완료 수행 시간: 141.6222
